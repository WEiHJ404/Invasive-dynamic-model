# %%
'''
Author: WEiHJ
Date: 2022-04-08 18:43:15
LastEditors: WEiHJ
LastEditTime: 2022-04-08 18:45:57
FilePath: /undefined/Users/weihj/Desktop/工作/2022/0408/四个城市数据整合.ipynb
Description: 

'''
import pandas as pd 
import matplotlib.pyplot as plt
import os

df = pd.read_excel('/Users/weihj/Desktop/工作/2022/3月/0321/不同场景模拟参数设置表格.xlsx',sheet_name='口罩、接触度')
df1 = pd.DataFrame()
b_dict = {}
list1 =df['降低幅度百分比']
list2 =df['M']


for i in range(len(list1)):
    b_dict[f'{list1[i]}'] = list2[i]
b_dict
allItems = os.listdir('/Users/weihj/Desktop/工作/2022/0413/上海/b/44')
for item in allItems:
    if item == '.DS_Store':
        pass
    else:
    # 
        file_path = os.path.join('/Users/weihj/Desktop/工作/2022/0413/上海/b/44',item)
        
        b_value = os.path.splitext(item)[0]
        print(b_value)
        measure_name = b_dict[f'{b_value}']
        df2 = pd.read_excel(file_path)
        df1[measure_name] =   df2['new_cases']  
df1.to_excel('/Users/weihj/Desktop/工作/2022/0413/上海/44/b.xlsx')
# Out:
# 0.206
# 0.713
# 0.617
# 0.683
# 0.338
# 0.508
# 0.158
# 0.699
# 0.499
# 0.122
# 0.17
# 0.285
# 0.544
# 0.401
# 0.397
# 0.488
# 0.236
# 0.365
# 0.113
# 0.27
# 0.305
# 0.647
# 0.128
# 0.07
# 0.466
# 0.326
# 0.166
# 0.218
# 0.598
# 0.404
# 0.351
# 0.192
# 0.413
# 0.556
# 0.034
# 0.608
# 0.258
# 0.262
# 0.274
# 0.793
# 0.117
# 0.183
# 0.642
# 0.341
# 0.789
# 0.475
# 0.072
# 0.032
# 0.589
# 0.622
# 0.481
# 0.706
# 0.751
# 0.0
# 0.784
# 0.229

# %%
#计算上海h值八个仓室新发病例数+并计算实际隔离率

import pandas as pd 
import os 
import numpy as np 
count = 0
allItems = os.listdir('/Users/weihj/Desktop/工作/2022/0413/上海/h/44')
for item in allItems:
    if item == '.DS_Store':
        pass
    else:
        print(item)
        h = os.path.splitext(item)[0]
        #拼接文件路径
        path = os.path.join('/Users/weihj/Desktop/工作/2022/0413/上海/h/44',item)
        #读取文件
        df = pd.read_excel(path)
        df = df.assign(Is1_newcases=np.nan,Is2_newcases =np.nan,A1_newcases=np.nan,A2_newcases=np.nan,R1_newcases=np.nan,
                                R2_newcases=np.nan,R3_newcases=np.nan,R4_newcases=np.nan)
        for i in range(df['Is1'].count()-1):
            df['R1_newcases'][i+1] = df['R1'][i+1]-df['R1'][i]+df['R1'][i]/4.5
            df['R2_newcases'][i+1] = df['R2'][i+1]-df['R2'][i]+df['R2'][i]/4.5
            df['R3_newcases'][i+1] = df['R3'][i+1]-df['R3'][i]+df['R3'][i]/4.5
            df['R4_newcases'][i+1] = df['R4'][i+1]-df['R4'][i]+df['R4'][i]/4.5
            h_reality = ((df['R2_newcases'].sum()+df['R4_newcases'].sum())/(df['R1_newcases'].sum()+df['R2_newcases'].sum()+df['R3_newcases'].sum()+df['R4_newcases'].sum()))
            if i ==998:
                print('结束')
                df.to_excel(f'/Users/weihj/Desktop/工作/2022/0413/上海/44/h_reality/{h}_{h_reality}.xlsx')
            else:
                continue
# Out:
# 0.3.xlsx
# /var/folders/cl/xgqrv30n0fd3b3bv6gpnh9tr0000gn/T/ipykernel_13859/4054698351.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['R1_newcases'][i+1] = df['R1'][i+1]-df['R1'][i]+df['R1'][i]/4.5
# /var/folders/cl/xgqrv30n0fd3b3bv6gpnh9tr0000gn/T/ipykernel_13859/4054698351.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['R2_newcases'][i+1] = df['R2'][i+1]-df['R2'][i]+df['R2'][i]/4.5
# /var/folders/cl/xgqrv30n0fd3b3bv6gpnh9tr0000gn/T/ipykernel_13859/4054698351.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import os
Path = '/Users/weihj/Desktop/工作/2022/0413/上海/44/h_reality'
list = []
allItems = os.listdir(Path)
df1 = pd.DataFrame()
h_dict = {}
list=[]
for item in allItems:
    if item == '.DS_Store':
        pass
    else:
        path = os.path.join(Path,item)
        df = pd.read_excel(path)
        h_name = os.path.splitext(item)[0]
        h_value = h_name.split('_')[0]
        h_relity_value = h_name.split('_')[1]
        h_relity_value = float(h_relity_value)
        h_relity_value = h_relity_value*100
        h_relity_value ='%.2f'%h_relity_value
        h_dict[f'{h_value}'] = h_relity_value
        df1[f'I_R_{h_relity_value}%'] =  df['new_cases']
        Measure_name = f'I_R_{h_relity_value}%'
        print(Measure_name)
df1.to_excel('/Users/weihj/Desktop/工作/2022/0413/上海/44/h_value.xlsx')
        # max_cases = df['new_cases'].max()
        # get_max_value_time = int(df['new_cases'].idxmax(axis=0))
        # Sustained_time = df['new_cases'][df['new_cases']>=1].count()+1
        # all_cases = df['new_cases'][df['new_cases']>=1].sum()
        # list.append([Measure_name,int(max_cases),get_max_value_time,Sustained_time,int(all_cases)])
        # print(Measure_name)
        # df1[Measure_name] = df['new_cases']
# df1.to_excel('shanghai_b.xlsx',index=False)
# df2 = pd.DataFrame(list,columns=['Measure','max_cases_value','get_max_cases_value_time','Sustained_time','all_cases'])
# df2 =  df2.sort_values(by='all_cases',ascending=False)
# df2.to_excel('/Users/weihj/Desktop/工作/2022/0408/四个城市效果/shanghai_h_value.xlsx',index=False)
# Out:
# I_R_57.09%
# I_R_66.36%
# I_R_64.53%
# I_R_18.46%
# I_R_47.31%
# I_R_69.32%
# I_R_61.24%
# I_R_51.76%
# I_R_49.64%
# I_R_68.66%
# I_R_26.58%
# I_R_63.51%
# I_R_58.58%
# I_R_59.96%
# I_R_31.14%
# I_R_53.69%
# I_R_35.15%
# I_R_69.95%
# I_R_70.53%
# I_R_62.42%
# I_R_41.89%
# I_R_65.47%
# I_R_67.94%
# I_R_44.74%
# I_R_38.71%
# I_R_67.18%
# I_R_55.46%

# %%
Path = '/Users/weihj/Desktop/工作/2022/0413/上海/bh/44'
allItems = os.listdir(Path)
df1 = pd.DataFrame()
list = []

for item in allItems:
    if item == '.DS_Store':
        pass
    else:
        path = os.path.join(Path,item)
        fileName = os.path.splitext(item)[0]
        b_value =fileName.split('_')[0]
        h_value =fileName.split('_')[1]
        df = pd.read_excel(path)
        # print(b_dict[b_value])
        # print(h_dict[h_value])
        # df1[f'{b_dict[b_value]}&I_R_{h_dict[h_value]}%'] = df['new_cases']
        print(f'{b_dict[b_value]}&I_R_{h_dict[h_value]}%')
        Measure_name = f'{b_dict[b_value]}&I_R_{h_dict[h_value]}%'
#         max_cases = df['new_cases'].max()
#         get_max_value_time = int(df['new_cases'].idxmax(axis=0))
#         Sustained_time = df['new_cases'][df['new_cases']>=1].count()+1
#         all_cases = df['new_cases'][df['new_cases']>=1].sum()
#         list.append([Measure_name,int(max_cases),get_max_value_time,Sustained_time,int(all_cases)])
#         # print(Measure_name)
        df1[Measure_name] = df['new_cases']
df1.to_excel('/Users/weihj/Desktop/工作/2022/0413/上海/bh/44/b_h_value.xlsx',index=False)
# df2 = pd.DataFrame(list,columns=['Measure','max_cases_value','get_max_cases_value_time','Sustained_time','all_cases'])
# df2 =  df2.sort_values(by='all_cases',ascending=False)
# df2.to_excel('/Users/weihj/Desktop/工作/2022/0408/四个城市效果/shanghai_bh_value.xlsx',index=False)


# df1.to_excel('shanghai_bh1.xlsx',index=False)
# Out:
# S_D_80%&M_10%&I_R_55.46%
# S_D_50%&M_40%&I_R_59.96%
# S_D_40%&M_10%&I_R_55.46%
# S_D_40%&M_10%&I_R_58.58%
# S_D_80%&M_10%&I_R_51.76%
# M_20%&I_R_47.31%
# S_D_40%&M_10%&I_R_51.76%
# S_D_80%&M_10%&I_R_58.58%
# S_D_80%&I_R_31.14%
# S_D_60%&M_40%&I_R_57.09%
# S_D_40%&M_10%&I_R_26.58%
# S_D_80%&M_10%&I_R_26.58%
# S_D_50%&M_40%&I_R_38.71%
# S_D_80%&M_30%&I_R_47.31%
# S_D_60%&M_40%&I_R_38.71%
# S_D_80%&M_30%&I_R_57.09%
# S_D_80%&M_50%&I_R_51.76%
# M_20%&I_R_55.46%
# S_D_80%&M_50%&I_R_58.58%
# S_D_60%&M_40%&I_R_47.31%
# M_20%&I_R_57.09%
# S_D_70%&M_50%&I_R_55.46%
# S_D_80%&M_50%&I_R_26.58%
# S_D_70%&M_50%&I_R_26.58%
# M_20%&I_R_51.76%
# S_D_80%&M_50%&I_R_55.46%
# M_20%&I_R_58.58%
# S_D_70%&M_50%&I_R_58.58%
# S_D_70%&M_50%&I_R_51.76%
# S_D_60%&M_40%&I_R_59.96%
# M_20%&I_R_26.58%
# S_D_40%&M_10%&I_R_59.96%
# S_D_80%&M_30%&I_R_61.24%
# M_50%&I_R_61.24%
# S_D_50%&M_40%&I_R_55.46%
# S_D_80%&M_10%&I_R_59.96%
# S_D_50%&M_40%&I_R_31.14%
# S_D_40%&M_10%&I_R_57.09%
# S_D_80%&M_50%&I_R_31.14%
# ...

# %%
'''
Author: WEiHJ
Date: 2022-04-08 18:43:15
LastEditors: WEiHJ
LastEditTime: 2022-04-08 18:45:57
FilePath: /undefined/Users/weihj/Desktop/工作/2022/0408/四个城市数据整合.ipynb
Description: 

'''
import pandas as pd 
import matplotlib.pyplot as plt
import os

df = pd.read_excel('/Users/weihj/Desktop/工作/2022/3月/0321/不同场景模拟参数设置表格.xlsx',sheet_name='口罩、接触度')
df1 = pd.DataFrame()
b_dict = {}
list1 =df['降低幅度百分比']
list2 =df['M']

for i in range(len(list1)):
    b_dict[f'{list1[i]}'] = list2[i]
list = []


Path = '/Users/weihj/Desktop/工作/2022/0413/上海/b/22'
allItems = os.listdir(Path)
for item in allItems:
    if item == '.DS_Store':
        pass
    else:
        path = os.path.join(Path,item)
        df = pd.read_excel(path)
        b_value = (os.path.splitext(item)[0])
        Measure_name = b_dict[b_value]
        max_cases = df['new_cases'].max()
        get_max_value_time = int(df['new_cases'].idxmax(axis=0))
        Sustained_time = df['new_cases'][df['new_cases']>=1].count()+1
        all_cases = df['new_cases'][df['new_cases']>=1].sum()
        list.append([Measure_name,int(max_cases),get_max_value_time,Sustained_time,int(all_cases)])
        # print(Measure_name)
        # df1[Measure_name] = df['new_cases']
# df1.to_excel('shanghai_b.xlsx',index=False)
        df2 = pd.DataFrame(list,columns=['Measure','max_cases_value','get_max_cases_value_time','Sustained_time','all_cases'])
df2 = df2.sort_values(by='all_cases',ascending=False)
df2
# df2.to_excel('/Users/weihj/Desktop/工作/2022/0416/上海/b/22.xlsx')
# df2.to_excel('/Users/weihj/Desktop/工作/2022/0413/上海/44/S_D_M_value.xlsx',index=False)
# df2.to_excel('/Users/weihj/Desktop/工作/2022/0408/四个城市效果/shanghai_b_value.xlsx',index=False)
# Out:
#           Measure  max_cases_value  get_max_cases_value_time  Sustained_time  \
# 53              0          1836285                        48             116
# 47  S_D_10%&M_10%          1794726                        49             118
# 34          M_10%          1792104                        49             118
# 23  S_D_10%&M_20%          1739252                        50             120
# 46  S_D_20%&M_10%          1736934                        50             120
# 18  S_D_20%&M_20%          1675891                        51             123
# 40          M_20%          1670020                        51             123
# 9   S_D_30%&M_10%          1661528                        51             124
# 22          M_30%          1649637                        51             124
# 6   S_D_10%&M_30%          1604111                        52             126
# 26  S_D_30%&M_20%          1586680                        52             127
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import os
Path = '/Users/weihj/Desktop/工作/2022/0413/上海/h_reality'
list = []
allItems = os.listdir(Path)
df1 = pd.DataFrame()
h_dict = {}
list=[]
for item in allItems:
    if item == '.DS_Store':
        pass
    else:
        path = os.path.join(Path,item)
        df = pd.read_excel(path)
        h_name = os.path.splitext(item)[0]
        h_value = h_name.split('_')[0]
        h_relity_value = h_name.split('_')[1]
        h_relity_value = float(h_relity_value)
        h_relity_value = h_relity_value*100
        h_relity_value ='%.2f'%h_relity_value
        h_dict[f'{h_value}'] = h_relity_value
        df1[f'I_R_{h_relity_value}%'] =  df['new_cases']

        Measure_name = f'I_R_{h_relity_value}%'
        max_cases = df['new_cases'].max()
        get_max_value_time = int(df['new_cases'].idxmax(axis=0))
        Sustained_time = df['new_cases'][df['new_cases']>=1].count()+1
        all_cases = df['new_cases'][df['new_cases']>=1].sum()
        list.append([Measure_name,int(max_cases),get_max_value_time,Sustained_time,int(all_cases)])
        # print(Measure_name)
        # df1[Measure_name] = df['new_cases']
# df1.to_excel('shanghai_b.xlsx',index=False)
df2 = pd.DataFrame(list,columns=['Measure','max_cases_value','get_max_cases_value_time','Sustained_time','all_cases'])
df2 =  df2.sort_values(by='all_cases',ascending=False)
df2
# df2.to_excel('/Users/weihj/Desktop/工作/2022/0413/上海/44/I_R_value.xlsx',index=False)

# df2.to_excel('/Users/weihj/Desktop/工作/2022/0408/四个城市效果/shanghai_h_value.xlsx',index=False)
# Out:
#        Measure  max_cases_value  get_max_cases_value_time  Sustained_time  \
# 3   I_R_18.46%          1504527                        53             130
# 10  I_R_26.58%          1427771                        53             131
# 14  I_R_31.14%          1377423                        53             132
# 16  I_R_35.15%          1327953                        53             134
# 24  I_R_38.71%          1279519                        53             135
# 20  I_R_41.89%          1232250                        53             137
# 23  I_R_44.74%          1186254                        53             138
# 4   I_R_47.31%          1141613                        53             140
# 8   I_R_49.64%          1098391                        53             142
# 7   I_R_51.76%          1056630                        53             144
# 15  I_R_53.69%          1016360                        53             145
# 26  I_R_55.46%           977592                        53             147
# ...

# %%
Path = '/Users/weihj/Desktop/工作/2022/0413/苏州/bh/4'
allItems = os.listdir(Path)
df1 = pd.DataFrame()
list = []

for item in allItems:
    if item == '.DS_Store':
        pass
    else:
        path = os.path.join(Path,item)
        fileName = os.path.splitext(item)[0]
        b_value =fileName.split('_')[0]
        h_value =fileName.split('_')[1]
        df = pd.read_excel(path)
        print(b_dict[b_value])
        print(h_dict[h_value])
        df1[f'{b_dict[b_value]}&I_R_{h_dict[h_value]}%'] = df['new_cases']
        
        Measure_name = f'{b_dict[b_value]}&I_R_{h_dict[h_value]}%'
        max_cases = df['new_cases'].max()
        get_max_value_time = int(df['new_cases'].idxmax(axis=0))
        Sustained_time = df['new_cases'][df['new_cases']>=1].count()+1
        all_cases = df['new_cases'][df['new_cases']>=1].sum()
        list.append([Measure_name,int(max_cases),get_max_value_time,Sustained_time,int(all_cases)])
        # print(Measure_name)
        # df1[Measure_name] = df['new_cases']
# df1.to_excel('shanghai_b.xlsx',index=False)
df2 = pd.DataFrame(list,columns=['Measure','max_cases_value','get_max_cases_value_time','Sustained_time','all_cases'])
df2 =  df2.sort_values(by='all_cases',ascending=False)
# df2.to_excel('/Users/weihj/Desktop/工作/2022/0408/四个城市效果/shanghai_bh_value.xlsx',index=False)
# df2.to_excel('/Users/weihj/Desktop/工作/2022/0413/上海/44/S_D_M_I_R_value.xlsx',index=False)

df2=df2[df2['all_cases']<=175601]
count= df2['all_cases'].count()
print(count)
# df1.to_excel('shanghai_bh1.xlsx',index=False)
# Out:
# S_D_80%&M_10%
# 55.46
# S_D_50%&M_40%
# 59.96
# S_D_40%&M_10%
# 55.46
# S_D_40%&M_10%
# 58.58
# S_D_80%&M_10%
# 51.76
# M_20%
# 47.31
# S_D_40%&M_10%
# 51.76
# S_D_80%&M_10%
# 58.58
# S_D_80%
# 31.14
# S_D_60%&M_40%
# 57.09
# S_D_40%&M_10%
# 26.58
# S_D_80%&M_10%
# 26.58
# S_D_50%&M_40%
# 38.71
# S_D_80%&M_30%
# 47.31
# S_D_60%&M_40%
# 38.71
# S_D_80%&M_30%
# 57.09
# S_D_80%&M_50%
# 51.76
# M_20%
# 55.46
# S_D_80%&M_50%
# 58.58
# S_D_60%&M_40%
# 47.31
# M_20%
# 57.09
# S_D_70%&M_50%
# 55.46
# S_D_80%&M_50%
# 26.58
# S_D_70%&M_50%
# 26.58
# M_20%
# 51.76
# S_D_80%&M_50%
# 55.46
# M_20%
# 58.58
# S_D_70%&M_50%
# 58.58
# S_D_70%&M_50%
# 51.76
# S_D_60%&M_40%
# 59.96
# M_20%
# 26.58
# S_D_40%&M_10%
# 59.96
# S_D_80%&M_30%
# 61.24
# M_50%
# 61.24
# S_D_50%&M_40%
# 55.46
# S_D_80%&M_10%
# 59.96
# S_D_50%&M_40%
# 31.14
# S_D_40%&M_10%
# 57.09
# S_D_80%&M_50%
# 31.14
# M_50%
# 57.09
# S_D_50%&M_40%
# 58.58
# S_D_50%&M_40%
# 51.76
# S_D_50%&M_40%
# 26.58
# S_D_80%&M_10%
# 38.71
# ...

# %%
import math
#苏州
p=0.31
w2=1/3.66
w=1/3.66
b=1.55218e-6
VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)
X=0.3635
S1 =(1-X)*12748262
S2= X*12748262
y =1/4.5
h=0
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 44.236115152022805

# %%
import math
#苏州阶段2
p=0.31
w2=1/3.66
w=1/3.66
b=4.72513e-16
VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)
X=0.3635
S1 =(1-X)*12748262
S2= X*12748262
y =1/4.5
h=0.05
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 1.123648819650986e-08

# %%
import math
#南京

w2=1/3.66
w=1/3.66
p=0.31
b=6.15336e-7
X=0.527

VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)

S1 =(1-X)*9310000
S2= X*9310000
y =1/4.5
h=0
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 11.855710320753955

# %%
import math
#南京2

w2=1/3.66
w=1/3.66
p=0.31
b=1.359e-15
X=0.527

VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)

S1 =(1-X)*9310000
S2= X*9310000
y =1/4.5
h=0.05
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 2.1848249853231324e-08

# %%
import math
#上海

w2=1/3.66
w=1/3.66
p=0.31
b=1.60431e-7
X=0.45

VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)

S1 =(1-X)*24870000
S2= X*24870000
y =1/4.5
h=0
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 8.591412330191952

# %%
import math
#上海2

w2=1/3.66
w=1/3.66
p=0.31
b=5.98562e-8
X=0.45

VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)

S1 =(1-X)*24870000
S2= X*24870000
y =1/4.5
h=0.05
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 2.674652443801519

# %%
import math
#深圳
w2=1/3.66
w=1/3.66
p=0.31
b=0.000000119634
X=0.6201

VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)

S1 =(1-X)*17560100
S2= X*17560100
y =1/4.5
h=0
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 4.103908484896832

# %%
import math
#深圳
w2=1/3.66
w=1/3.66
p=0.31
b=0.0000000000000105372
X=0.6201

VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)

S1 =(1-X)*17560100
S2= X*17560100
y =1/4.5
h=0.05
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 3.0161310585337426e-07

# %%
import math
#深圳3
w2=1/3.66
w=1/3.66
p=0.31
b=0.0000000657162
X=0.6201

VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)

S1 =(1-X)*17560100
S2= X*17560100
y =1/4.5
h=0.05
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 1.881037390092388

# %%
import math
#深圳4
w2=1/3.66
w=1/3.66
p=0.31
b=0.0000000998531
X=0.6201

VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)

S1 =(1-X)*17560100
S2= X*17560100
y =1/4.5
h=0.05
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 2.8581600064616373

# %%
import math
#深圳4
w2=1/3.66
w=1/3.66
p=0.31
b=1.07805E-15
X=0.6201

VES1=0.5267
VEI1=0
VES2=0.7499
VEI2=0.07
b11=b*(1-VES1)*(1-VEI1)
b12=b*(1-VES2)*(1-VEI1)
b21=b*(1-VES1)*(1-VEI2)
b22=b*(1-VES2)*(1-VEI2)

S1 =(1-X)*17560100
S2= X*17560100
y =1/4.5
h=0.05
w1=1


R21 = (p*w2/(p*w2+(1-p)*w))*(b21*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S1/(y+h))
R22 = (p*w2/(p*w2+(1-p)*w))*(b22*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b22*S2/(y+h))

R11 = (p*w2/(p*w2+(1-p)*w))*(b11*S1/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b11*S1/(y+h))
R12 = (p*w2/(p*w2+(1-p)*w))*(b21*S2/(y+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(w1+h))+((1-p)*w/(p*w2+(1-p)*w))*(b21*S2/(y+h))

max_value = (R11+R22 +((R11+R22)**2-4*(R11*R22-R12*R21))**0.5)/2
print(max_value)
# Out:
# 3.0857723946136555e-08
