# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
df =pd.read_excel('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/shenzhen/shenzhen_b_25.xlsx',sheet_name='M')
plt.rcParams['font.sans-serif'] = 'Times New Roman'
plt.rcParams.update({'font.size': 20})
color_list = ['',
'#e70101',
'#f32b2d',
'#fc454c',
'#ff5c68',
'#ff7383',
'#ff889c',
'#ff9db2',
'#ffb1c6',
'#ffc5d8',
'#fbd9e6',
]
fig,ax = plt.subplots(figsize=(18,8))
for i in range(1,11):
    ax.plot(df['Date'][1:],df.iloc[:,i][1:],label=df.iloc[:,i][0],color=color_list[i],linewidth=3)
plt.legend()
dt1 = datetime.datetime(2022,1,31)
dt2 = datetime.datetime(2022,12,31)
plt.xlim(dt1,dt2)
plt.ylim(0,7*10e4)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)
plt.text(0.005, 0.95, s="M 2 Shenzhen City", transform=ax.transAxes,size=26)
plt.savefig('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/Shenzhen_M.pdf', dpi=300, bbox_inches = 'tight')

# %%
df =pd.read_excel('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/shenzhen/shenzhen_b_25.xlsx',sheet_name='S_D')
plt.rcParams['font.sans-serif'] = 'Times New Roman'
plt.rcParams.update({'font.size': 20})
fig,ax = plt.subplots(figsize=(18,8))
color_list=[    
'',    
'#131eff',
'#005bff',
'#0079ff',
'#008dff',
'#009ef0',
'#00acd6',
'#00b8c0',
'#5ac2b4',
'#9acab6',
'#c6d2c8',
]
for i in range(1,11):
    ax.plot(df['Date'][1:],df.iloc[:,i][1:],label=df.iloc[:,i][0],color=color_list[i],linewidth=3)
plt.legend()
dt1 = datetime.datetime(2022,1,31)
dt2 = datetime.datetime(2022,12,31)
plt.xlim(dt1,dt2)
plt.ylim(0,7*10e4)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)
plt.text(0.005, 0.95, s="S_D 2 Shenzhen City", transform=ax.transAxes,size=26)
plt.savefig('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/Shenzhen_S_D.pdf', dpi=300, bbox_inches = 'tight')

# %%
df =pd.read_excel('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/shenzhen/shenzhen_b_25.xlsx',sheet_name='S_D_M')
plt.rcParams['font.sans-serif'] = 'Times New Roman'
plt.rcParams.update({'font.size': 20})
fig,ax = plt.subplots(figsize=(18,8))
color_list=[
'',
'#b604e3',
'#b80ae3',
'#ba10e2',
'#bc16e2',
'#bd1be1',
'#bf21e1',
'#c127e0',
'#c32de0',
'#c533e0',
'#c739df',
'#c93fdf',
'#cb45de',
'#cc4ade',
'#ce50dd',
'#d056dd',
'#d25cdc',
'#d462dc',
'#d668dc',
'#d86edb',
'#da74db',
'#db79da',
'#dd7fda',
'#df85d9',
'#e18bd9',
'#e391d9',
'#e597d8',
'#e79dd8',
'#e9a3d7',
'#eaa8d7',
'#ecaed6',
'#eeb4d6',
'#f0bad5',
'#f2c0d5',
'#f4c6d5',
'#f6ccd4',
'#f8d2d4',
'#f9d7d3',
'#fbddd3',
'#fde3d2',
'#ffe9d2',
'#fcd5c6',
'#fddfcc',
'#ffe9d2',

]
for i in range(1,43):
    ax.plot(df['Date'][1:],df.iloc[:,i][1:],label=df.iloc[:,i][0],color=color_list[i])
# plt.legend()
dt1 = datetime.datetime(2022,1,31)
dt2 = datetime.datetime(2022,12,31)
plt.xlim(dt1,dt2)
plt.ylim(0,7*10e4)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)
plt.text(0.005, 0.95, s="S_D&M 2 Shenzhen City", transform=ax.transAxes,size=26)
# plt.legend(bbox_to_anchor=(1.1, 0.5), loc=3, borderaxespad=0,frameon=False)
plt.savefig('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/Shenzhen_S_D_M.pdf', dpi=300, bbox_inches = 'tight')

# %%
df =pd.read_excel('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/shenzhen/shenzhen_h_25.xlsx',sheet_name='h')
plt.rcParams['font.sans-serif'] = 'Times New Roman'
plt.rcParams.update({'font.size': 20})
fig,ax = plt.subplots(figsize=(18,8))
color_list=[
'',
'#dc0048',
'#de0a4e',
'#df1454',
'#e34304',
'#e44c0d',
'#e65414',
'#e75c1b',
'#e86422',
'#e96b29',
'#eb722f',
'#ec7836',
'#ed7f3d',
'#ee8543',
'#ef8b4a',
'#f09151',
'#f19758',
'#f29d5f',
'#f3a367',
'#f4a86e',
'#f5ae76',
'#f6b47e',
'#f7b986',
'#f8bf8d',
'#f9c496',
'#fac99e',
'#fbcfa6',
'#fcd4af',
'#fcd9b7',
'#fddfc0',
'#fee4c9',
'#ffe9d2',
]
for i in range(1,26):
    ax.plot(df['Date'][1:],df.iloc[:,i][1:],label=df.iloc[:,i][0],color=color_list[i])
# plt.legend()
dt1 = datetime.datetime(2022,3,1)
dt2 = datetime.datetime(2022,12,31)
plt.xlim(dt1,dt2)
plt.ylim(0,7*10e4)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)
plt.text(0.005, 0.95, s="I_R 2 Shenzhen City", transform=ax.transAxes)
# plt.legend(bbox_to_anchor=(1.1, 0.5), loc=3, borderaxespad=0,frameon=False)
plt.savefig('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/Shenzhen_h.pdf', dpi=300, bbox_inches = 'tight')

# %%
df =pd.read_excel('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/shenzhen/shenzhen_bh_25.xlsx',sheet_name='b_h')
plt.rcParams['font.sans-serif'] = 'Times New Roman'
plt.rcParams.update({'font.size': 20})
fig,ax = plt.subplots(figsize=(18,8))
color_list = [
'',
'#1adc00',
'#1ddc03',
'#20db05',
'#23db08',
'#25db0a',
'#28da0d',
'#2bda0f',
'#2eda12',
'#31da14',
'#34d917',
'#36d919',
'#39d91c',
'#3cd81e',
'#3fd821',
'#42d824',
'#45d726',
'#48d729',
'#4ad72b',
'#4dd62e',
'#50d630',
'#53d633',
'#56d635',
'#59d538',
'#5bd53a',
'#5ed53d',
'#61d43f',
'#64d442',
'#67d445',
'#6ad347',
'#6dd34a',
'#6fd34c',
'#72d24f',
'#75d251',
'#78d254',
'#7bd256',
'#7ed159',
'#80d15b',
'#83d15e',
'#86d060',
'#89d063',
'#89d063',
'#8cd161',
'#8ed15e',
'#91d25c',
'#94d359',
'#96d357',
'#99d454',
'#9cd452',
'#9ed54f',
'#a1d64d',
'#a4d64a',
'#a6d748',
'#a9d845',
'#acd843',
'#aed941',
'#b1da3e',
'#b4da3c',
'#b6db39',
'#b9dc37',
'#bcdc34',
'#bedd32',
'#c1dd2f',
'#c4de2d',
'#c6df2a',
'#c9df28',
'#cce025',
'#cee123',
'#d1e121',
'#d4e21e',
'#d6e31c',
'#d9e319',
'#dce417',
'#dee514',
'#e1e512',
'#e4e60f',
'#e6e60d',
'#e9e70a',
'#ece808',
'#eee805',
'#f1e903',
'#f1e903',
'#f1e90d',
'#f1ea17',
'#f1ea21',
'#f2eb2c',
'#f2eb36',
'#f2ec40',
'#f2ec4a',
'#f2ed54',
'#f2ed5e',
'#f2ee68',
'#f3ee73',
'#f3ef7d',
'#f3ef87',
'#f3f091',
'#f3f09b',
'#f3f1a5',
'#f3f1af',
'#f4f2ba',
'#f4f2c4',
'#f4f3ce',
'#f4f3d8',


]
for i in range(1,101):
    ax.plot(df['Date'][1:],df.iloc[:,i][1:],label=df.iloc[:,i][0],color=color_list[i])
# plt.legend()
dt1 = datetime.datetime(2022,3,1)
dt2 = datetime.datetime(2022,12,31)
plt.xlim(dt1,dt2)
plt.ylim(0,7*10e4)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)
plt.text(0.005, 0.95, s="Comprehensive Control_2 Shenzhen City", transform=ax.transAxes)
# plt.legend(bbox_to_anchor=(1.1, 0.5), loc=3, borderaxespad=0,frameon=False)
plt.savefig('/Users/weihj/Desktop/工作/2022/COVID_article/四个城市181情况模拟/Shenzhen_bh.pdf', dpi=300, bbox_inches = 'tight')
