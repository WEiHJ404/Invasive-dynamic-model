# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
df_shanghai = pd.read_excel('/Users/weihj/Desktop/工作/2022/0405/迁出率.xlsx',sheet_name='上海')
df_shenzhen = pd.read_excel('/Users/weihj/Desktop/工作/2022/0405/迁出率.xlsx',sheet_name='深圳')
df_nanjing = pd.read_excel('/Users/weihj/Desktop/工作/2022/0405/迁出率.xlsx',sheet_name='南京')
df_suzhou = pd.read_excel('/Users/weihj/Desktop/工作/2022/0405/迁出率.xlsx',sheet_name='苏州')

plt.rcParams['font.sans-serif'] = 'Times New Roman'
plt.rcParams.update({'font.size': 20})
fig,ax = plt.subplots(2,2,figsize=(36,15))


dt2 = datetime.datetime(2022,3,1)
dt3 = datetime.datetime(2022,3,7)
dt4 = datetime.datetime(2022,3,24)
dt5 = datetime.datetime(2022,4,2)
dt6 = datetime.datetime(2022,4,15)
# ax.axvspan(dt1,dt2,facecolor='#FCF0E9')
ax[0][0].axvspan(dt2,dt3,facecolor='#F4DDD5')
ax[0][0].axvspan(dt3,dt4,facecolor='#E5D1CE')
ax[0][0].axvspan(dt4,dt5,facecolor='#DDC2C8')
ax[0][0].axvspan(dt5,dt6,facecolor='#DDD9E7')
plt.xlim(dt2,dt6)
ax[0][0].bar(df_shanghai['时间'],df_shanghai['Confirmed Cases'],color='#2673B7',alpha=1,label='Confirmed Cases')
ax[0][0].bar(df_shanghai['时间'],df_shanghai['Asymptomatic Cases'],bottom=df_shanghai['Confirmed Cases'],color='lightskyblue',alpha=0.5,label='Asymptomatic Cases')
ax[0][0].plot(df_shanghai['时间'],df_shanghai['中间'],color='red',label='Threshold Value of SpillOutRisk')
ax[0][0].fill_between(df_shanghai['时间'],df_shanghai['上限'],df_shanghai['下限'],color='red',alpha=0.3,label='Threshold Value of SpillOutRisk')
# ax[0][0].legend()

dt7 =datetime.datetime(2022,3,1)
dt8 =datetime.datetime(2022,4,13)
ax[0][0].set_xlim(dt7,dt8)

dt2 = datetime.datetime(2022,1,31)
dt3 = datetime.datetime(2022,2,6)
dt4 = datetime.datetime(2022,2,18)
dt5 = datetime.datetime(2022,3,3)
dt6 = datetime.datetime(2022,3,31)

# ax.axvspan(dt1,dt2,facecolor='#FCF0E9')
ax[0][1].axvspan(dt2,dt3,facecolor='#F4DDD5')
ax[0][1].axvspan(dt3,dt4,facecolor='#E5D1CE')
ax[0][1].axvspan(dt4,dt5,facecolor='#DDC2C8')
ax[0][1].axvspan(dt5,dt6,facecolor='#DDD9E7')
ax[0][1].bar(df_shenzhen['时间'],df_shenzhen['Confirmed Cases'],color='#2673B7',alpha=1,label='Confirmed Cases')
ax[0][1].bar(df_shenzhen['时间'],df_shenzhen['Asymptomatic Cases'],bottom=df_shenzhen['Confirmed Cases'],color='lightskyblue',alpha=0.5,label='Asymptomatic Cases')
ax[0][1].plot(df_shenzhen['时间'],df_shenzhen['中间'],color='red')
ax[0][1].fill_between(df_shenzhen['时间'],df_shenzhen['上限'],df_shenzhen['下限'],color='red',alpha=0.3)
dt7 =datetime.datetime(2022,1,31)
dt8 =datetime.datetime(2022,3,31)
ax[0][1].set_xlim(dt7,dt8)


dt2 = datetime.datetime(2022,3,10)
dt3 = datetime.datetime(2022,3,16)
dt4 = datetime.datetime(2022,3,31)
dt5 = datetime.datetime(2022,4,2)
dt6 = datetime.datetime(2022,5,5)

# ax.axvspan(dt1,dt2,facecolor='#FCF0E9')
ax[1][0].axvspan(dt2,dt3,facecolor='#F4DDD5')
ax[1][0].axvspan(dt3,dt4,facecolor='#E5D1CE')
ax[1][0].axvspan(dt4,dt5,facecolor='#DDC2C8')

ax[1][0].axvspan(dt5,dt6,facecolor='#DDD9E7')
ax[1][0].bar(df_nanjing['时间'],df_nanjing['Confirmed Cases'],color='#2673B7',alpha=1,label='Confirmed Cases')
ax[1][0].bar(df_nanjing['时间'],df_nanjing['Asymptomatic Cases'],bottom=df_nanjing['Confirmed Cases'],color='lightskyblue',alpha=0.5,label='Asymptomatic Cases')
ax[1][0].plot(df_nanjing['时间'],df_nanjing['中间'],color='red')
ax[1][0].fill_between(df_nanjing['时间'],df_nanjing['上限'],df_nanjing['下限'],color='red',alpha=0.3)
dt7 =datetime.datetime(2022,3,10)
dt8 =datetime.datetime(2022,3,31)
ax[1][0].set_xlim(dt7,dt8)

# dt1 = datetime.datetime(2022,2,10)
dt2 = datetime.datetime(2022,2,10)
dt3 = datetime.datetime(2022,2,16)
dt4 = datetime.datetime(2022,3,3)
dt5 = datetime.datetime(2022,3,30)
dt6 = datetime.datetime(2022,5,5)

# ax.axvspan(dt1,dt2,facecolor='#FCF0E9')
ax[1][1].axvspan(dt2,dt3,facecolor='#F4DDD5')
ax[1][1].axvspan(dt3,dt4,facecolor='#E5D1CE')
# ax[1][1].axvspan(dt4,dt5,facecolor='#DDC2C8')
# ax[1][1].axvspan(dt5,dt6,facecolor='#DDD9E7')

ax[1][1].bar(df_suzhou['时间'],df_suzhou['Confirmed Cases'],color='#2673B7',alpha=1,label='Confirmed Cases')
ax[1][1].bar(df_suzhou['时间'],df_suzhou['Asymptomatic Cases'],bottom=df_suzhou['Confirmed Cases'],color='lightskyblue',alpha=0.5,label='Asymptomatic Cases')
ax[1][1].plot(df_suzhou['时间'],df_suzhou['中间'],color='red')
ax[1][1].fill_between(df_suzhou['时间'],df_suzhou['上限'],df_suzhou['下限'],color='red',alpha=0.3)
dt7 =datetime.datetime(2022,2,10)
dt8 =datetime.datetime(2022,3,3)
ax[1][1].set_xlim(dt7,dt8)
plt.text(0.005, 0.93, s="b1: Shanghai City", transform=ax[0][0].transAxes,size=26)#调整布局
plt.text(0.005, 0.93, s="b2: Shenzhen City", transform=ax[0][1].transAxes,size=26)#调整布局
plt.text(0.005, 0.93, s="b3: Nanjing City", transform=ax[1][0].transAxes,size=26)#调整布局
plt.text(0.005, 0.93, s="b4: Suzhou City", transform=ax[1][1].transAxes,size=26)#调整布局
plt.savefig('/Users/weihj/Desktop/工作/2022/0414/外溢.pdf',dpi=300)
